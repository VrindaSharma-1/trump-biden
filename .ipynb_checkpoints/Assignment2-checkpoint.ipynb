# %%
import pandas as pd
from string import punctuation
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %% [markdown]
# # Part B

# %%
tweets = pd.read_csv('6ktweets.csv')

def remove_punctuation(item):
    for p in punctuation:
        item = item.lstrip().replace(p,'')
    return item

def conv_lowercase(x):
    return x.lower()

tweets['clean_tweets'] = tweets['tweets'].apply(remove_punctuation).apply(conv_lowercase)
#tweets

# %%
# nltk.download()
tweets['word_freq_list'] = tweets['clean_tweets'].apply(word_tokenize).apply(set).apply(list)

# Remove stop words
stop_words = set(stopwords.words('english'))
def remove_stopwords(s):
    return [w for w in s if not w in stop_words] 

tweets['word_freq_list'] = tweets['word_freq_list'].apply(remove_stopwords)

# Creating a list of all the words in the comments to count word frequency in the next step
count = []
for i in range(len(tweets)):
    count+=tweets['word_freq_list'][i]

# %%
# fetching the frequency of words
from nltk import FreqDist
word_freq = nltk.FreqDist(count)

# %%
#identified key issues

#trump issues
immigration = ['mexican', 'wall', 'immigrate', 'mexico', 'illegals', 'immigrants', 'immigrant']
impeach = ['impeachment', 'impeached', 'trumpimpeachment', 'impeachtrump']
foreign_relations = ['ukraine', 'isis', 'syria', 'china' ,'iran']

#biden issues
economy = ['job', 'jobs', 'money', 'taxes', 'taxpayer', 'economys', 'trumpeconomy']
education = [ 'college', 'school' ,'educate' ,'students' , 'student']
gun_control = ['control','weapons', 'weapon','guns', 'gun']

#replacements for trump and biden
trump = ['donaldtrump', 'realdonaldtrump',  'trump2020','trumps', 'donald' ]
biden = ['joebiden', 'joes','bidens', 'joe']

attributes = immigration + impeach+ foreign_relations + economy + trump + biden +education + gun_control

# %%
#replacing words with key issues
key_issues = pd.DataFrame()
key_issues['attribute'] = attributes
key_issues['general_attribute'] = ''

key_issues['general_attribute'][0:len(immigration)] = 'immigration'
key_issues['general_attribute'][len(immigration):len(immigration)+len(impeach)] = 'impeach'
key_issues['general_attribute'][len(immigration)+len(impeach):len(immigration)+len(impeach)+len(foreign_relations)] = 'foreign_relations'
key_issues['general_attribute'][len(immigration)+len(impeach)+len(foreign_relations):len(immigration)+len(impeach)+len(foreign_relations)+len(economy)] = 'economy'
key_issues['general_attribute'][len(immigration)+len(impeach)+len(foreign_relations)+ len(economy):len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump)] = 'trump'
key_issues['general_attribute'][len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump):len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump)+len(biden)] = 'biden'
key_issues['general_attribute'][len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump)+ len(biden):len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump)+len(biden) + len(education)] = 'education'
key_issues['general_attribute'][len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump)+ len(biden)+ len(gun_control):len(immigration)+len(impeach)+len(foreign_relations)+len(economy)+len(trump)+len(biden) + len(education)+len(gun_control)] = 'gun_control'
#key_issues

# %%
def word_to_attributes(s):
    s = " ".join(str(x) for x in s)
    for i in key_issues.index.values:
        s = s.replace(key_issues["attribute"][i].lower(),key_issues["general_attribute"][i].lower())
    return s

tweets['comments_attributes_replace'] = tweets['word_freq_list'].apply(word_to_attributes)

# %% [markdown]
# # Part C

# %%
#making list of tweets that mention trump and list of tweets that mention biden
all_ = tweets['comments_attributes_replace'].apply(word_tokenize).apply(set).apply(list)
all_ = all_.tolist()
t =[]
b =[]
for i in all_: 
    for j in set(i):
        if j == 'trump':
            t.append(i)
        elif j == 'biden':
            b.append(i)

# %%
#calculating total no of tweets that mention each of these key issues
economy =[]
immigration =[]
foreign_relations=[]
impeach=[]
for j in all_:
    for k in j:
        if k == 'economy':
            economy.append(j)
        if k == 'immigration':
            immigration.append(j)
        if k =='foreign_relations':
            foreign_relations.append(j)
        if k == 'impeach':
            impeach.append(j)

# %%
economy_immigration =[]
economy_foreign=[]
economy_impeach=[]
for j in economy:
    for k in j:
        if k == 'immigration':
            economy_immigration.append(j)
        if k =='foreign_relations':
            economy_foreign.append(j)
        if k == 'impeach':
            economy_impeach.append(j)   
len(economy_impeach)
# Out:
# 2

# %%
foreign_immigration =[]
foreign_impeach=[]
for j in foreign_relations:
    for k in j:
        if k == 'immigration':
            foreign_immigration.append(j)
        if k == 'impeach':
            foreign_impeach.append(j)   
len(foreign_impeach)
# Out:
# 10

# %%
impeach_immigration =[]
for j in impeach:
    for k in j:
        if k == 'immigration':
            impeach_immigration.append(j)
len(impeach_immigration)
# Out:
# 0

# %%
#calculating total number of tweets that mention both key issues and trump
economy_trump =[]
immigration_trump =[]
foreign_relations_trump=[]
impeach_trump =[]
trump_biden =[]
for j in t:
    for k in j:
        if k == 'economy':
            economy_trump.append(j)
        if k == 'immigration':
            immigration_trump.append(j)
        if k =='foreign_relations':
            foreign_relations_trump.append(j)
        if k == 'impeach':
            impeach_trump.append(j)   
        if k == 'biden':
            trump_biden.append(j)  
len(trump_biden)
# Out:
# 46

# %%
#calculating total number of tweets that mention both key issues and biden
economy_biden =[]
immigration_biden =[]
foreign_relations_biden=[]
impeach_biden =[]
biden_trump =[]
for c in b:
    for b1 in set(c):
        if b1 == 'economy':
            economy_biden.append(c)
            continue;
        if b1 == 'immigration':
            immigration_biden.append(c)
            continue; 
        if b1 =='foreign_relations':
            foreign_relations_biden.append(c) 
            continue;
        if b1 == 'impeach':
            impeach_biden.append(c)  
        if b1 == 'trump':
            biden_trump.append(c)             
len(biden_trump)
# Out:
# 46

# %%
#lift analysis for trump and biden

#trump
lift_economy_trump = (len(tweets)*len(economy_trump))/(len(t)*len(economy))
lift_immigration_trump = (len(tweets)*len(immigration_trump))/(len(t)*len(immigration))
lift_foriegn_relations_trump = (len(tweets)*len(foreign_relations_trump))/(len(t)*len(foreign_relations))
lift_impeach_trump = (len(tweets)*len(impeach_trump))/(len(t)*len(impeach))

#biden
lift_economy_biden = (len(tweets)*len(economy_biden))/(len(b)*len(economy))
lift_immigration_biden = (len(tweets)*len(immigration_biden))/(len(b)*len(immigration))
lift_foriegn_relations_biden = (len(tweets)*len(foreign_relations_biden))/(len(b)*len(foreign_relations))
lift_impeach_biden = (len(tweets)*len(impeach_biden))/(len(b)*len(impeach))

#both
lift_trump_biden = (len(tweets)*len(trump_biden))/(len(b)*len(t))

#economy analysis
lift_economy_immigration = (len(tweets)*len(economy_immigration))/(len(immigration)*len(economy))
lift_economy_foreign =(len(tweets)*len(economy_foreign))/(len(economy)*len(foreign_relations))
lift_economy_impeach = (len(tweets)*len(economy_impeach))/(len(impeach)*len(economy))

#foreign relations
lift_foreign_immigration =(len(tweets)*len(foreign_immigration))/(len(immigration)*len(foreign_relations))
lift_foreign_impeach = (len(tweets)*len(foreign_impeach))/(len(impeach)*len(foreign_relations))

lift_impeach_immigration = (len(tweets)*len(impeach_immigration))/(len(impeach)*len(immigration))

# %%
data = [[1, lift_trump_biden , lift_economy_trump, lift_immigration_trump, lift_foriegn_relations_trump, lift_impeach_trump], [lift_trump_biden, 1, lift_economy_biden, lift_immigration_biden, lift_foriegn_relations_biden,lift_impeach_biden], [lift_economy_trump,lift_economy_biden,1,lift_economy_immigration,lift_economy_foreign,lift_economy_impeach],[lift_immigration_trump,lift_immigration_biden,lift_economy_immigration,1,lift_foreign_immigration,lift_impeach_immigration],[lift_foriegn_relations_trump,lift_foriegn_relations_biden,lift_economy_foreign,lift_foreign_immigration,1,lift_foreign_impeach],[lift_impeach_trump,lift_impeach_biden,lift_economy_impeach,lift_impeach_immigration,lift_foreign_impeach,1]]
lift = pd.DataFrame(data, columns = ['Trump', 'Biden', 'Economy', 'Immigration', 'Foreign Relations', 'Impeach'])
lift.rename(index = {0: "Trump", 1:"Biden", 2:"Economy", 3:"Immigration", 4:"Foreign Relations", 5:"Impeach"},  inplace = True)

# %%
lift1 = lift.round(3)
lift1
# Out:
#                    Trump  Biden  Economy  Immigration  Foreign Relations  \
# Trump              1.000  1.104    0.678        1.157              1.318
# Biden              1.104  1.000    1.794        0.622              2.490
# Economy            0.678  1.794    1.000        1.351              2.102
# Immigration        1.157  0.622    1.351        1.000              0.000
# Foreign Relations  1.318  2.490    2.102        0.000              1.000
# Impeach            1.713  0.398    0.865        0.000              2.667
#
#                    Impeach
# Trump                1.713
# Biden                0.398
# Economy              0.865
# Immigration          0.000
# Foreign Relations    2.667
# Impeach              1.000

# %%
#forming window around tweets that mention trump and issues

from nltk.tokenize.treebank import TreebankWordDetokenizer
impeach_sentiment_trump=[]
economy_sentiment_trump=[]
immigration_sentiment_trump=[]
foreign_relations_sentiment_trump=[]
for s in impeach_trump:
    for i in range(len(s)):
        if s[i] =='impeach':
            impeach_sentiment_trump.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))
            
for s in economy_trump:
    for i in range(len(s)):
        if s[i] =='economy':
            economy_sentiment_trump.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))

for s in immigration_trump:
    for i in range(len(s)):
        if s[i] =='immigration':
            immigration_sentiment_trump.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))

for s in foreign_relations_trump:
    for i in range(len(s)):
        if s[i] =='foreign_relations':
            foreign_relations_sentiment_trump.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))

# %%
#forming window around tweets that mention biden and issues
impeach_sentiment_biden=[]
economy_sentiment_biden=[]
immigration_sentiment_biden=[]
foreign_relations_sentiment_biden=[]
for s in impeach_biden:
    for i in range(len(s)):
        if s[i] =='impeach':
            impeach_sentiment_biden.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))
            
for s in economy_biden:
    for i in range(len(s)):
        if s[i] =='economy':
            economy_sentiment_biden.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))

for s in immigration_biden:
    for i in range(len(s)):
        if s[i] =='immigration':
            immigration_sentiment_biden.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))

for s in foreign_relations_biden:
    for i in range(len(s)):
        if s[i] =='foreign_relations':
            foreign_relations_sentiment_biden.append(TreebankWordDetokenizer().detokenize(s[i-3:i+3]))

# %%
#performing sentiment analysis 

from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

def sentiment_analysis(list_):

    sia = SIA()
    r = []

    for i in list_:
        score_ = sia.polarity_scores(i)
        r.append(score_)
    sum_=0
    for i in range(len(r)):
        sum_ = sum_ + r[i]['compound']
    return sum_

# %%
#getting lift scores for all key issues for each candidate

impeach_sentiment_t= sentiment_analysis(impeach_sentiment_trump)
economy_sentiment_t= sentiment_analysis(economy_sentiment_trump)
immigration_sentiment_t =sentiment_analysis(immigration_sentiment_trump)
foreign_relations_sentiment_t= sentiment_analysis(foreign_relations_sentiment_trump)

impeach_sentiment_b = sentiment_analysis(impeach_sentiment_biden)
economy_sentiment_b= sentiment_analysis(economy_sentiment_biden)
immigration_sentiment_b =sentiment_analysis(immigration_sentiment_biden)
foreign_relations_sentiment_b= sentiment_analysis(foreign_relations_sentiment_biden)

# %%
data = [[economy_sentiment_t, immigration_sentiment_t, foreign_relations_sentiment_t, impeach_sentiment_t], [economy_sentiment_b, immigration_sentiment_b, foreign_relations_sentiment_b,impeach_sentiment_b]]
sentiment = pd.DataFrame(data, columns = ['Economy', 'Immigration', 'Foreign Relations', 'Impeach'])
sentiment.rename(index = {0: "Trump", 1:"Biden"},  inplace = True)

# %%
sentiment
# Out:
#        Economy  Immigration  Foreign Relations  Impeach
# Trump  -0.1092       0.9736             2.2416   0.0253
# Biden  -0.3049       0.6369            -0.6828   0.0000

# %%
# Out:
# C:\Users\Vrinda Sharma\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\Vrinda Sharma\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
import numpy as np
#Scaling the values to bring to a normalized scale
lift1.replace(0,0.01,inplace=True)
lift1 = np.log(lift1)

# %%
#Scaling the two values for better repersentation on the plot

lift1['Foreign Relations']['Trump'] = 0.01
lift1['Foreign Relations']['Biden'] = 0.25
lift1['Trump']['Foreign Relations'] = 0.01
lift1['Biden']['Foreign Relations'] = 0.25
lift1 = lift1.round(3)

# %%
import matplotlib.pyplot as plt

# Calculating the similarity matrix which is the input for plotting MDS plot
similarity_matrix = lift1
np.fill_diagonal(similarity_matrix.values, 0)


# Plotting MDS plot
from sklearn import manifold
seed = np.random.RandomState(seed=3)
mds = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9, 
      random_state=seed, dissimilarity="precomputed", n_jobs=1)
results = mds.fit(similarity_matrix)
coords = results.embedding_

plt.subplots_adjust(bottom = 0.1)
plt.scatter(
    coords[:, 0], coords[:, 1], marker = 'o'
    )
for label, x, y in zip(lift1, coords[:, 0], coords[:, 1]):
    
    plt.annotate(
        label,
        xy = (x, y), xytext = (-30, 30),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.65', fc = 'purple', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0.25'))

plt.title('Similarity Plot')
plt.show()

# %% [markdown]
# ### Part E

# %%
## get top ten cities of each state
Michigan = ['Detroit','Grand Rapids','Warren', 'Sterling Heights','Ann Arbor','Lansing','Flint','Dearborn','Livonia','Troy']
Pennsylvania = ['Philadelphia','Pittsburgh','Allentown','Erie','Reading','Upper Darby','Scranton','Bethlehem','Lancaster','Millcreek']
Wisconsin = ['Milwaukee','Madison','Green Bay','Kenosha','Racine','Appleton','Waukesha','Eau Claire','Oshkosh','Janesville']

# %%
## make the city name all lower case
mi = []
for x in Michigan:
    mi.append(x.lower())
    
pen = []
for x in Pennsylvania:
    pen.append(x.lower())
    
wi = []
for x in Wisconsin:
    wi.append(x.lower())

# %%
threestates = []
for x in tweets['User Location'].unique():
    if 'michigan' in str(x).lower() or 'pennsylvania'in str(x).lower() or 'wisconsin' in str(x).lower() or str(x).lower().endswith(', mi') or str(x).lower().endswith('pa') or str(x).lower().endswith('wi') or str(x).lower() in mi or str(x).lower() in pen or str(x).lower() in wi:
        threestates.append(x)

threestates
# Out:
# ['Michigan, USA',
#  'Pennsylvania',
#  'Green Bay',
#  'Pennsylvania, USA',
#  'Verona WI',
#  'Altoona PA',
#  'Wisconsin, USA',
#  'Lehigh Valley PA',
#  'DELCO Phila, Pa',
#  'Philadelphia, PA',
#  'Eastern PA',
#  'Warren, PA',
#  'Butler, PA',
#  'Philadelphia',
#  'Somewhere in Pennsylvania!',
#  'Little Chute, WI',
#  'Easton, PA',
#  'Holt, MI',
#  'Grand Blanc, MI',
#  'Pittsburgh, PA',
#  'Tempe, AZ & Door County, WI',
#  'Waterford, PA',
#  'Lebanon, PA',
#  'Monaca, PA',
#  'Wisconsin, USA ',
#  'Loganville, PA',
#  'Michigan U.S.A.',
#  'Near Pittsburgh PA',
#  'Western Pa',
#  'Detroit, MI',
#  'Huntingdon Valley, PA',
#  'Oakland County, Mi',
#  'Cranberry Township, PA',
#  'Hobart, WI',
#  'Lancaster, PA',
#  'Clinton, MI',
#  'Southfield, MI',
#  'Michigan',
#  'Lock Haven, PA',
#  'Ligonier, PA',
#  'Davidsville, PA',
#  'New York / Pennsylvania',
#  'Mt. Pleasant Michigan',
#  'Milwaukee',
#  'Superior, WI',
#  'Port Huron, MI',
#  'PA']

# %%
for index, row in tweets.iterrows():
    if row['User Location'] in threestates:
        tweets.loc[index,'User Location'] = 'battleground'

# %%
data1 = tweets.copy()
data1[data1['User Location'] == 'battleground']
# Out:
#       Unnamed: 0              Date  \
# 13            13   10/14/2019 0:35
# 32            32   10/14/2019 0:24
# 54            54   10/14/2019 0:04
# 155          155  10/13/2019 22:45
# 164          164  10/13/2019 22:38
# 179          179  10/13/2019 22:26
# 203          203  10/13/2019 22:15
# 212          212  10/13/2019 22:06
# 214          214  10/13/2019 22:05
# 245          245  10/13/2019 21:42
# 269          269  10/13/2019 21:27
# 306          306  10/13/2019 21:04
# 365          365  10/13/2019 20:26
# 412          412  10/13/2019 19:41
# 443          443  10/13/2019 19:21
# 514          514  10/13/2019 18:32
# 517          517  10/13/2019 18:31
# 519          519  10/13/2019 18:30
# 611          611  10/13/2019 17:20
# 613          613  10/13/2019 17:20
# 615          615  10/13/2019 17:18
# 636          636  10/13/2019 17:02
# 649          649  10/13/2019 16:53
# 688          688  10/13/2019 16:33
# 767          767  10/13/2019 15:42
# 814          814  10/13/2019 15:04
# 819          819  10/13/2019 15:00
# 829          829  10/13/2019 14:55
# 842          842  10/13/2019 14:47
# 844          844  10/13/2019 14:47
# ...          ...               ...
# 4464        4464  10/11/2019 14:05
# 4535        4535  10/11/2019 13:21
# 4736        4736  10/11/2019 11:34
# 4797        4797  10/11/2019 11:02
# 4809        4809  10/11/2019 10:52
# 4812        4812  10/11/2019 10:51
# 4839        4839  10/11/2019 10:17
# 4845        4845  10/11/2019 10:06
# 4847        4847  10/11/2019 10:05
# 4867        4867   10/11/2019 9:18
# 4910        4910   10/11/2019 7:13
# 4917        4917   10/11/2019 6:58
# 4970        4970   10/11/2019 6:11
# 5003        5003   10/11/2019 5:36
# 5197        5197   10/11/2019 3:26
# 5258        5258   10/11/2019 3:13
# 5275        5275   10/11/2019 3:09
# 5313        5313   10/11/2019 3:00
# 5326        5326   10/11/2019 2:59
# 5466        5466   10/11/2019 2:38
# 5474        5474   10/11/2019 2:36
# 5515        5515   10/11/2019 2:29
# 5684        5684   10/11/2019 1:31
# 5694        5694   10/11/2019 1:29
# 5793        5793   10/11/2019 1:11
# 5888        5888   10/11/2019 0:47
# 5900        5900   10/11/2019 0:46
# 5905        5905   10/11/2019 0:44
# 5908        5908   10/11/2019 0:44
# 5933        5933   10/11/2019 0:39
#
#                                                  tweets User Location  \
# 13    @NBCNews Unfounded?  You people are nuts!  Oh ...  battleground
# 32                  @BillKristol Drunk again? #MAGA2020  battleground
# 54    @DavidJHarrisJr @realDonaldTrump That would of...  battleground
# 155   No matter how hard they try to hinder our abil...  battleground
# 164   @thehill @realDonaldTrump You don’t speak for ...  battleground
# 179   @MargaretheBrac2 If you listen to the Presiden...  battleground
# 203   #tcot #ccot #LNYHBT #maga2020 #ycot Do you thi...  battleground
# 212   #tcot #ccot #LNYHBT #maga2020 #ycot @TexGOP  I...  battleground
# 214   @DavidJHarrisJr @realDonaldTrump Nice photo bo...  battleground
# 245   Um? 🤔 How many average voters want our troops ...  battleground
# 269   #tcot #ccot #maga2020 #lnyhbt @tedcruz  @theHi...  battleground
# 306   #tcot #ccot #maga2020 #LNYHBT #ycot Too late. ...  battleground
# 365   #GoRedStateByState \n#TrumpLandslide2020 \n#Wi...  battleground
# 412   #TrumpISIS #MVP\nTrump is a Traitor. Trump gav...  battleground
# 443   Did you see this coming? How come so many did ...  battleground
# 514   @IlhanMN Really? @IlhanMN wants to talk about ...  battleground
# 517   Oh they get it #MAGA2020 They just love Russia...  battleground
# 519   @OnlyGod4ever @mentoringwithm1 Did my part!  #...  battleground
# 611   @RepAdamSchiff What part of Article 2 don't yo...  battleground
# 613   ATTENTION:  #MAGA #MAGA2020 https://t.co/SfB0o...  battleground
# 615            Time to be America! #trump2020 #MAGA2020  battleground
# 636   @ericish @RepSwalwell Is this a joke?  Not onc...  battleground
# 649   2014 photo shows earlier ties between @realDon...  battleground
# 688   @BarbaraBoxer Your confusing @realDonaldTrump ...  battleground
# 767   @baalter @DDonsmith007 They lie till they get ...  battleground
# 814   @HillaryClinton Benghazi, Obama Red Line etc.....  battleground
# 819   @asheborn57 So in other words he will continue...  battleground
# 829   #TrumpGenocide #MAGA #MAGA2020 #KAG #Trump2020...  battleground
# 842   @Scaramucci @realDonaldTrump Indeed there is.....  battleground
# 844   @ktlin60 @davidph36485368 @Krm1285A @Michael_m...  battleground
# ...                                                 ...           ...
# 4464  #MinneapolisTrumpRally #TrumpMinneapolis #Trum...  battleground
# 4535  Drain the swamp #MAGA2020 #KAG https://t.co/Px...  battleground
# 4736  Stand and Deliver 🇺🇸\nThey did just that! \n\n...  battleground
# 4797  @IlhanMN Keep on Trumpin Patriots!! America de...  battleground
# 4809  @RealCandaceO Girl please...only liberal dims ...  battleground
# 4812  Morning thoughts: \nGood always concurs evil !...  battleground
# 4839  @tracybeanz @AmericanP2019 @RonDeSantisFL @Rep...  battleground
# 4845  But nothing to see here they say. \n#MAGA2020 ...  battleground
# 4847  @realDonaldTrump I hope you take my home state...  battleground
# 4867  @MattFinnFNC Cops look cool, collected, and pr...  battleground
# 4910  @RealSaavedra So if you disagree with the core...  battleground
# 4917  @IlhanMN #MN05 needs a Rep that wants to #MAGA...  battleground
# 4970  @efrostee @MPRnews @Miksh995 Go TRUMP! #MAGA 🇺...  battleground
# 5003  @Ken19512 @IDFWUMF My guy @RepFredKeller is Ha...  battleground
# 5197  Hmmmmm? I can’t wait for that IG repot! #Trump...  battleground
# 5258  I’d post a #highlight reel of the #TrumpRallyM...  battleground
# 5275  Fox News is crap. \nListening to this idiot sa...  battleground
# 5313  I guess this jagoff thinks think  all us #MAGA...  battleground
# 5326  A little something for you folks to chew on as...  battleground
# 5466  @thehill @realDonaldTrump I don’t think so eit...  battleground
# 5474  How many of these protesters were paid for by ...  battleground
# 5515  @JackPosobiec @Luv2Fish2017 Go home to mommy. ...  battleground
# 5684  @ThomasPKennedy3 Best president ever Big T #MA...  battleground
# 5694  There ya go @Jacob_Frey #MAGA2020 #MAGASOTA ht...  battleground
# 5793        @T_S_P_O_O_K_Y @FoxNews No way!!! #MAGA2020  battleground
# 5888  I agree, @charliekirk11 !#MAGA2020 https://t.c...  battleground
# 5900  Minneapolis police officer running against Ilh...  battleground
# 5905  David Bossie: Impeachment inquiry? No, America...  battleground
# 5908  @SpeakerPelosi @RepAdamSchiff Fact:  only way ...  battleground
# 5933  Time to support the beautiful women of Team #M...  battleground
#
#         hashtag                                       clean_tweets  \
# 13    #MAGA2020  nbcnews unfounded  you people are nuts  oh wai...
# 32    #MAGA2020                   billkristol drunk again maga2020
# 54    #MAGA2020  davidjharrisjr realdonaldtrump that would of m...
# 155   #MAGA2020  no matter how hard they try to hinder our abil...
# 164   #MAGA2020  thehill realdonaldtrump you don’t speak for th...
# 179   #MAGA2020  margarethebrac2 if you listen to the president...
# 203   #MAGA2020  tcot ccot lnyhbt maga2020 ycot do you think th...
# 212   #MAGA2020  tcot ccot lnyhbt maga2020 ycot texgop  it is i...
# 214   #MAGA2020  davidjharrisjr realdonaldtrump nice photo bomb...
# 245   #MAGA2020  um 🤔 how many average voters want our troops i...
# 269   #MAGA2020  tcot ccot maga2020 lnyhbt tedcruz  thehill why...
# 306   #MAGA2020  tcot ccot maga2020 lnyhbt ycot too late damage...
# 365   #MAGA2020  goredstatebystate \ntrumplandslide2020 \nwisco...
# 412   #MAGA2020  trumpisis mvp\ntrump is a traitor trump gave c...
# 443   #MAGA2020  did you see this coming how come so many did b...
# 514   #MAGA2020  ilhanmn really ilhanmn wants to talk about mor...
# 517   #MAGA2020  oh they get it maga2020 they just love russia ...
# 519   #MAGA2020  onlygod4ever mentoringwithm1 did my part  maga...
# 611   #MAGA2020  repadamschiff what part of article 2 dont you ...
# 613   #MAGA2020        attention  maga maga2020 httpstcosfb0oyjkkr
# 615   #MAGA2020              time to be america trump2020 maga2020
# 636   #MAGA2020  ericish repswalwell is this a joke  not once d...
# 649   #MAGA2020  2014 photo shows earlier ties between realdona...
# 688   #MAGA2020  barbaraboxer your confusing realdonaldtrump wi...
# 767   #MAGA2020  baalter ddonsmith007 they lie till they get el...
# 814   #MAGA2020  hillaryclinton benghazi obama red line etc sta...
# 819   #MAGA2020  asheborn57 so in other words he will continue ...
# 829   #MAGA2020  trumpgenocide maga maga2020 kag trump2020lands...
# 842   #MAGA2020  scaramucci realdonaldtrump indeed there is sta...
# 844   #MAGA2020  ktlin60 davidph36485368 krm1285a michaelme mar...
# ...         ...                                                ...
# 4464  #MAGA2020  minneapolistrumprally trumpminneapolis trumpra...
# 4535  #MAGA2020    drain the swamp maga2020 kag httpstcopx6n0hkjye
# 4736  #MAGA2020  stand and deliver 🇺🇸\nthey did just that \n\nt...
# 4797  #MAGA2020  ilhanmn keep on trumpin patriots america depen...
# 4809  #MAGA2020  realcandaceo girl pleaseonly liberal dims beli...
# 4812  #MAGA2020  morning thoughts \ngood always concurs evil \n...
# 4839  #MAGA2020  tracybeanz americanp2019 rondesantisfl repmatt...
# 4845  #MAGA2020  but nothing to see here they say \nmaga2020 ht...
# 4847  #MAGA2020  realdonaldtrump i hope you take my home state ...
# 4867  #MAGA2020  mattfinnfnc cops look cool collected and profe...
# 4910  #MAGA2020  realsaavedra so if you disagree with the core ...
# 4917  #MAGA2020  ilhanmn mn05 needs a rep that wants to maga202...
# 4970  #MAGA2020  efrostee mprnews miksh995 go trump maga 🇺🇸\nma...
# 5003  #MAGA2020  ken19512 idfwumf my guy repfredkeller is hanco...
# 5197  #MAGA2020  hmmmmm i can’t wait for that ig repot trumpmin...
# 5258  #MAGA2020  i’d post a highlight reel of the trumprallymin...
# 5275  #MAGA2020  fox news is crap \nlistening to this idiot say...
# 5313  #MAGA2020  i guess this jagoff thinks think  all us maga2...
# 5326  #MAGA2020  a little something for you folks to chew on as...
# 5466  #MAGA2020  thehill realdonaldtrump i don’t think so eithe...
# 5474  #MAGA2020  how many of these protesters were paid for by ...
# 5515  #MAGA2020  jackposobiec luv2fish2017 go home to mommy ant...
# 5684  #MAGA2020  thomaspkennedy3 best president ever big t maga...
# 5694  #MAGA2020  there ya go jacobfrey maga2020 magasota httpst...
# 5793  #MAGA2020                    tspooky foxnews no way maga2020
# 5888  #MAGA2020  i agree charliekirk11 maga2020 httpstcovo4vppymfe
# 5900  #MAGA2020  minneapolis police officer running against ilh...
# 5905  #MAGA2020  david bossie impeachment inquiry no americans ...
# 5908  #MAGA2020  speakerpelosi repadamschiff fact  only way tru...
# 5933  #MAGA2020  time to support the beautiful women of team ma...
#
#                                          word_freq_list  \
# 13    [youre, never, wait, nbc, oh, mind, nbcnews, u...
# 32                       [maga2020, billkristol, drunk]
# 54    [maga, would, last, even, better, davidjharris...
# 155   [stay, trump, matter, try, positive, train, ab...
# 164   [magats, trumpin, american, ’, trumpers, speak...
# 179   [president, every, listen, speech, take…, un, ...
# 203   [media, operative, tcot, biased, httpstcox4gpt...
# 212   [ccot, ycot, texgop, believe, ridiculously, co...
# 214   [nice, davidjharrisjr, bomb, photo, realdonald...
# 245   [average, thank, um, many, answer, syria, c…, ...
# 269   [ccot, tedcruz, reporting, courtmar…, lnyhbt, ...
# 306   [late, tcot, clintons, done, maga2020, reputat...
# 365   [w…, trumplandslide2020, speech, nancy, pelosi...
# 412   [maga, maga2020landslide, comfort, isis, gave,...
# 443   [many, illegitimatepresident, trump, see, come...
# 514   [ilhanmn, really, wants, corruptdemocrats, mor...
# 517   [russia, traitors, states, them…, oh, maga2020...
# 519     [onlygod4ever, mentoringwithm1, maga2020, part]
# 611   [understand, repadamschiff, article, dont, rec...
# 613     [attention, maga, maga2020, httpstcosfb0oyjkkr]
# 615                [trump2020, america, maga2020, time]
# 636   [presidents, joke, speak, article, 2, right…, ...
# 649   [realdonaldtrump, gop…, shows, indicted, ties,...
# 688   [thanks, playing, confusing, barbaraboxer, bar...
# 767   [said, be…, opposite, gon, ddonsmith007, baalt...
# 814   [realdonaldtrump, stay, lane, etc, obama, hill...
# 819   [foreign, asheborn57, work, words, continue, m...
# 829   [maga, trumpgenocide, never, trumpsupporters…,...
# 842   [scaramucci, indeed, stay, religious, maga2020...
# 844   [dazipstahh, sweetkat111, davidph36485368, krm...
# ...                                                 ...
# 4464  [minneapolistrumprally, maga, trumprallymn, qa...
# 4535  [drain, kag, httpstcopx6n0hkjye, maga2020, swamp]
# 4736  [thank, httpstcoslc4f5gdrc, stand, 🙏minneapoli...
# 4797  [ilhanmn, president, realdonaldtrump, depends,...
# 4809  [trump2020landslidevictory, wwg1wga, dims, bel...
# 4812  [morning, good, always, evil, trumpminneapolis...
# 4839  [americanp2019, tomfitton…, tracybeanz, repmat...
# 4845  [nothing, say, httpstcoic9z8ka6uj, maga2020, see]
# 4847  [take, maga, need, change, hope, home, magasot...
# 4867  [professional, trump2020, cops, scene, mattfin...
# 4910  [remove, beto, realsaavedra, beliefs, status, ...
# 4917  [vote, make, hash…, needs, httpstcoyi55yrbrjz,...
# 4970  [maga, go, miksh995, httpstcotilbpntayx, count...
# 5003  [keller2020, 👊💪👍🇺🇸, trump2020, ken19512, hanco...
# 5197  [repot, wait, ’, hmmmmm, ig, draintheswamp, tr...
# 5258  [minutes, lon…, ’, post, reel, httpstcoaguvhuv...
# 5275  [spewed, bigotry, news, idiot, course, hatred,...
# 5313  [jagoff, thinks, jail, hahah, httpstcolnbphvsl...
# 5326  [boy, amp, folks, chew, lunacy, yourwelcome…, ...
# 5466  [httpstcovojoznaqws, whenever, either, ’, spea...
# 5474      [paid, many, democrats, protesters, maga2020]
# 5515  [antifabrats, go, antifa, idiots, home, jackpo...
# 5684  [president, ever, big, maga2020, thomaspkenned...
# 5694  [go, jacobfrey, ya, magasota, httpstcotrcmbjpm...
# 5793                  [way, foxnews, tspooky, maga2020]
# 5888  [httpstcovo4vppymfe, agree, maga2020, charliek...
# 5900  [calls, happ…, absentee, constituents, minneap...
# 5905  [inquiry, conclusion, impeachment, david, witn...
# 5908  [reelected, way, 2020, repadamschiff, speakerp...
# 5933  [women, maga, team, trump2020, give, rt, maga2...
#
#                             comments_attributes_replace
# 13    youre never wait nbc oh mind nbcnews unfounded...
# 32                           maga2020 billkristol drunk
# 54    maga would last even better davidjharrisjr mad...
# 155   stay trump matter try positive train ability h...
# 164   magats trumpin american ’ trumpers speak us ma...
# 179   president every listen speech take… un httpstc...
# 203   media operative tcot biased httpstcox4gpt7xwrf...
# 212   ccot ycot texgop believe ridiculously condesce...
# 214   nice davidjharrisjr bomb photo realtrump maga2020
# 245   average thank um many answer foreign_relations...
# 269   ccot tedcruz reporting courtmar… lnyhbt httpst...
# 306   late tcot clintons done maga2020 reputationthe...
# 365   w… trumplandslide2020 speech nancy pelosi http...
# 412   maga maga2020landslide comfort foreign_relatio...
# 443   many illegitimatepresident trump see come ’ fr...
# 514   ilhanmn really wants corruptdemocrats morals v...
# 517   russia traitors states them… oh maga2020 get u...
# 519          onlygod4ever mentoringwithm1 maga2020 part
# 611   understand repadamschiff article dont recogniz...
# 613          attention maga maga2020 httpstcosfb0oyjkkr
# 615                         trump america maga2020 time
# 636   presidents joke speak article 2 right… httpstc...
# 649   realtrump gop… shows indicted ties rudygiulian...
# 688   thanks playing confusing barbaraboxer barackob...
# 767   said be… opposite gon ddonsmith007 baalter lie...
# 814   realtrump stay lane etc obama hillaryclinton b...
# 819     foreign asheborn57 work words continue maga2020
# 829   maga trumpgenocide never trumpupporters… happe...
# 842   scaramucci indeed stay religious maga2020 ongo...
# 844   dazipstahh sweetkat111 davidph36485368 krm1285...
# ...                                                 ...
# 4464  minneapolistrumprally maga trumprallymn qanon ...
# 4535        drain kag httpstcopx6n0hkjye maga2020 swamp
# 4736  thank httpstcoslc4f5gdrc stand 🙏minneapolistru...
# 4797  ilhanmn president realtrump depends patriots p...
# 4809  trumplandslidevictory wwg1wga dims believe lib...
# 4812  morning good always evil trumpminneapolis frid...
# 4839  americanp2019 tomfitton… tracybeanz repmattgae...
# 4845        nothing say httpstcoic9z8ka6uj maga2020 see
# 4847  take maga need change hope home magasota maga2...
# 4867  professional trump cops scene mattfinnfnc libs...
# 4910  remove beto realsaavedra beliefs status wants ...
# 4917  vote make hash… needs httpstcoyi55yrbrjz 2020 ...
# 4970  maga go miksh995 httpstcotilbpntayx country mp...
# 5003  keller2020 👊💪👍🇺🇸 trump ken19512 hancocked idfw...
# 5197  repot wait ’ hmmmmm ig draintheswamp trumpminn...
# 5258  minutes lon… ’ post reel httpstcoaguvhuvrh4 tr...
# 5275  spewed bigotry news idiot course hatred listen...
# 5313  jagoff thinks jail hahah httpstcolnbphvslo0 gu...
# 5326  boy amp folks chew lunacy yourwelcome… sinks h...
# 5466  httpstcovojoznaqws whenever either ’ speak thi...
# 5474            paid many democrats protesters maga2020
# 5515  antifabrats go antifa idiots home jackposobiec...
# 5684   president ever big maga2020 thomaspkennedy3 best
# 5694  go jacobfrey ya magasota httpstcotrcmbjpmzl ma...
# 5793                       way foxnews tspooky maga2020
# 5888    httpstcovo4vppymfe agree maga2020 charliekirk11
# 5900  calls happ… absentee constituents minneapolis ...
# 5905  inquiry conclusion impeach david witnessing bo...
# 5908  reelected way 2020 repadamschiff speakerpelosi...
# 5933  women maga team trump give rt maga2020… time f...
#
# [144 rows x 8 columns]

# %%
data1 = data1.dropna().copy()
data1.loc[data1['User Location'] == 'battleground','tweets'] = 'battleground' + data1['tweets']
data1
# Out:
#       Unnamed: 0             Date  \
# 0              0  10/14/2019 0:47
# 1              1  10/14/2019 0:46
# 3              3  10/14/2019 0:45
# 4              4  10/14/2019 0:45
# 5              5  10/14/2019 0:44
# 6              6  10/14/2019 0:44
# 7              7  10/14/2019 0:41
# 8              8  10/14/2019 0:41
# 10            10  10/14/2019 0:40
# 11            11  10/14/2019 0:37
# 13            13  10/14/2019 0:35
# 15            15  10/14/2019 0:35
# 16            16  10/14/2019 0:35
# 17            17  10/14/2019 0:35
# 18            18  10/14/2019 0:34
# 21            21  10/14/2019 0:33
# 22            22  10/14/2019 0:32
# 24            24  10/14/2019 0:30
# 27            27  10/14/2019 0:28
# 28            28  10/14/2019 0:27
# 29            29  10/14/2019 0:25
# 30            30  10/14/2019 0:25
# 31            31  10/14/2019 0:24
# 32            32  10/14/2019 0:24
# 34            34  10/14/2019 0:21
# 35            35  10/14/2019 0:20
# 38            38  10/14/2019 0:15
# 41            41  10/14/2019 0:12
# 42            42  10/14/2019 0:12
# 43            43  10/14/2019 0:11
# ...          ...              ...
# 5951        5951  10/11/2019 0:35
# 5953        5953  10/11/2019 0:33
# 5955        5955  10/11/2019 0:33
# 5956        5956  10/11/2019 0:33
# 5957        5957  10/11/2019 0:33
# 5959        5959  10/11/2019 0:32
# 5961        5961  10/11/2019 0:31
# 5962        5962  10/11/2019 0:31
# 5963        5963  10/11/2019 0:30
# 5965        5965  10/11/2019 0:30
# 5967        5967  10/11/2019 0:30
# 5970        5970  10/11/2019 0:27
# 5971        5971  10/11/2019 0:26
# 5972        5972  10/11/2019 0:26
# 5976        5976  10/11/2019 0:24
# 5977        5977  10/11/2019 0:24
# 5978        5978  10/11/2019 0:23
# 5983        5983  10/11/2019 0:21
# 5984        5984  10/11/2019 0:21
# 5985        5985  10/11/2019 0:21
# 5986        5986  10/11/2019 0:21
# 5987        5987  10/11/2019 0:21
# 5989        5989  10/11/2019 0:20
# 5990        5990  10/11/2019 0:20
# 5991        5991  10/11/2019 0:20
# 5993        5993  10/11/2019 0:19
# 5994        5994  10/11/2019 0:19
# 5995        5995  10/11/2019 0:18
# 5997        5997  10/11/2019 0:17
# 5998        5998  10/11/2019 0:17
#
#                                                  tweets  \
# 0     Why do they keep electing elites that have mil...
# 1     No Shame! \nThanks @carlosrossimc for the vers...
# 3     @realDonaldTrump @FoxNews needs to dump Wallac...
# 4     President Trump is 100% Correct on Syria Withd...
# 5                  @JoeBiden Poor Joe...#MAGA #MAGA2020
# 6     Found a useful idiot from the left who interru...
# 7     ICYMI Fort Worth police kill woman inside her ...
# 8     @EricTrump @LaraLeaTrump Wishing you happy bir...
# 10    In case I haven't said it this week.\n#Winning...
# 11    .@realDonaldTrump is the FOUNDER OF ISIS\n\n#w...
# 13    battleground@NBCNews Unfounded?  You people ar...
# 15    oh yeah libtards? conservatives cant cook? jus...
# 16    Well, well, well... I knew these assholes were...
# 17    @GOPLeader Can’t wait for the day that you are...
# 18    @RepLeeZeldin “Cherry Picking”, Representative...
# 21    @AnnieGabstonH @DebraMessing @googlenews Anoth...
# 22    @KokeReport Exactly what @POTUS expected. Exce...
# 24    @KipHenley Nice week. Pay that mortgage. #MAGA...
# 27    @realDonaldTrump @marklevinshow @FoxNews Hands...
# 28    #MAGA #MAGA2020 \n@realDonaldTrump has now mad...
# 29    @SaraCarterDC @realDonaldTrump @RepAdamSchiff ...
# 30    @Martina @RichardGrenell @mattlashey Aaand on ...
# 31    Following all fellow patriots! #MAGA2020 #MAGA...
# 32      battleground@BillKristol Drunk again? #MAGA2020
# 34    @realDonaldTrump @foxandfriends #maga #MAGA202...
# 35    @DavidJHarrisJr Not just No! But HELL NO!!! #M...
# 38    @thehowie @realDonaldTrump You obviously watch...
# 41            For you #MAGA2020 https://t.co/iPDVvLnVBe
# 42    #Frenchquarter you have a Pepper Palace at #1 ...
# 43    @pjbowles4 @MeltingInMarana @rkline56 @AlexPat...
# ...                                                 ...
# 5951  Great job fellas!🇺🇸 @CNN ✌#MAGA2020 \n#CNNisPa...
# 5953  @realDonaldTrump  Loves #America\nHe Loves Us\...
# 5955  @MaryUlinger @JohnTrumpFanKJV I like your atti...
# 5956        @HoarseWisperer Event is back on. #MAGA2020
# 5957  Could NOT HAVE SAID IT BETTER, @w_terrence!!! ...
# 5959  @realDonaldTrump @jairbolsonaro The mainstream...
# 5961  Time is on Trump's side!!  Kicking off the #Mi...
# 5962  #TrumpMinneapolis\n\nDamn. People in rural Ame...
# 5963  @TheSpeaker2018 What the?!? \n\nIn reality, I ...
# 5965  @PatriotCitizen4 @disneyhero323 In hopes maga ...
# 5967  Awesome! Retweet to keep it sweet! #MAGA2020 h...
# 5970  Watching now. \nHis campaigning style is what ...
# 5971  I have never been polled and voting for #Trump...
# 5972  @Pismo_B @erin2vankude @IlhanMN #ThursdayMotiv...
# 5976  Watching live. Super excited. #MAGA2020 #KAG20...
# 5977  Dear #MAGA2020, when Trump denied knowing Giul...
# 5978  @JudicialWatch I wish you all would leave this...
# 5983  @BetteMidler @AdamParkhomenko I love @ewarren ...
# 5984  @RepAdamSchiff This is more than ‘removing’ a ...
# 5985  Thought this was a blue state😂😂#KAG2020 #MAGA2...
# 5986  Incredible MAGA Meetup in PA tonight full of s...
# 5987  How #FakeNewsMedia Outlets Are In the Front Li...
# 5989  @Richzeoli interesting choice should really ta...
# 5990  @GOPChairwoman @BWWings @realDonaldTrump Hey L...
# 5991  Watching The Trump Rally!!!!\n#MAGA2020!!!!\nU...
# 5993  Thank you to all my friends for sharing pictur...
# 5994  Thank you to all my friends for sharing pictur...
# 5995  Trump’s children take in millions overseas as ...
# 5997  🚨BREAKING🚨\n#Whistleblower Worked With #JoeBid...
# 5998  Gosh, imagine that- a spineless business failu...
#
#                        User Location    hashtag  \
# 0                      United States  #MAGA2020
# 1                      United States  #MAGA2020
# 3                         Boston, MA  #MAGA2020
# 4                 Florida of course!  #MAGA2020
# 5                     Corpus Christi  #MAGA2020
# 6                Whereabouts, U.S.A.  #MAGA2020
# 7                                USA  #MAGA2020
# 8             Columbia, Maryland USA  #MAGA2020
# 10       North America - East & West  #MAGA2020
# 11                             Vegas  #MAGA2020
# 13                      battleground  #MAGA2020
# 15                          valhalla  #MAGA2020
# 16     Camp Pendleton via Pittsburgh  #MAGA2020
# 17                              Utah  #MAGA2020
# 18                          New York  #MAGA2020
# 21    Chicago, LA, Atlanta, Phoenix   #MAGA2020
# 22          ÜT: 35.271458,-82.503049  #MAGA2020
# 24                      On the Couch  #MAGA2020
# 27                     New York, NY   #MAGA2020
# 28                 Deep in the heart  #MAGA2020
# 29            kaikkialla läsnä oleva  #MAGA2020
# 30                          New York  #MAGA2020
# 31       Southern NH •  AmericaFirst  #MAGA2020
# 32                      battleground  #MAGA2020
# 34                   Westminster, CO  #MAGA2020
# 35                    New Castle, IN  #MAGA2020
# 38                  Connecticut, USA  #MAGA2020
# 41                 San Francisco, CA  #MAGA2020
# 42                        Tennessee   #MAGA2020
# 43                    MiddleOFTheSea  #MAGA2020
# ...                              ...        ...
# 5951                             ☮✝️  #MAGA2020
# 5953                  Tennessee, USA  #MAGA2020
# 5955                              🇺🇸  #MAGA2020
# 5956                   knoxville, tn  #MAGA2020
# 5957            Flyover Country, USA  #MAGA2020
# 5959        A galaxy far, far way...  #MAGA2020
# 5961                              MN  #MAGA2020
# 5962                   United States  #MAGA2020
# 5963                   United States  #MAGA2020
# 5965                     Chicago, IL  #MAGA2020
# 5967                  South Carolina  #MAGA2020
# 5970       close to Kim Jong Un's 🏠   #MAGA2020
# 5971         Greater Pittsburgh Area  #MAGA2020
# 5972                    Florida, USA  #MAGA2020
# 5976                   Colorado, USA  #MAGA2020
# 5977                   United States  #MAGA2020
# 5978                  Middle Georgia  #MAGA2020
# 5983                San Clemente, CA  #MAGA2020
# 5984                             USA  #MAGA2020
# 5985                       Ohio, USA  #MAGA2020
# 5986                  Washington, DC  #MAGA2020
# 5987             Hell's Kitchen, USA  #MAGA2020
# 5989                   Gulfcoast Fla  #MAGA2020
# 5990                        NYC/NJ🇺🇸  #MAGA2020
# 5991                     San Antonio  #MAGA2020
# 5993                  Minnesota, USA  #MAGA2020
# 5994                  Minnesota, USA  #MAGA2020
# 5995                    Portland, OR  #MAGA2020
# 5997                             USA  #MAGA2020
# 5998                    Freehold, NJ  #MAGA2020
#
#                                            clean_tweets  \
# 0     why do they keep electing elites that have mil...
# 1     no shame \nthanks carlosrossimc for the verse\...
# 3     realdonaldtrump foxnews needs to dump wallace ...
# 4     president trump is 100 correct on syria withdr...
# 5                        joebiden poor joemaga maga2020
# 6     found a useful idiot from the left who interru...
# 7     icymi fort worth police kill woman inside her ...
# 8     erictrump laraleatrump wishing you happy birth...
# 10    in case i havent said it this week\nwinning is...
# 11    realdonaldtrump is the founder of isis\n\nwinn...
# 13    nbcnews unfounded  you people are nuts  oh wai...
# 15    oh yeah libtards conservatives cant cook just ...
# 16    well well well i knew these assholes were lyin...
# 17    gopleader can’t wait for the day that you are ...
# 18    repleezeldin “cherry picking” representative z...
# 21    anniegabstonh debramessing googlenews another ...
# 22    kokereport exactly what potus expected excelle...
# 24       kiphenley nice week pay that mortgage maga2020
# 27    realdonaldtrump marklevinshow foxnews hands do...
# 28    maga maga2020 \nrealdonaldtrump has now made u...
# 29    saracarterdc realdonaldtrump repadamschiff tru...
# 30    martina richardgrenell mattlashey aaand on you...
# 31    following all fellow patriots maga2020 maga202...
# 32                     billkristol drunk again maga2020
# 34    realdonaldtrump foxandfriends maga maga2020 ma...
# 35      davidjharrisjr not just no but hell no maga2020
# 38    thehowie realdonaldtrump you obviously watch o...
# 41                  for you maga2020 httpstcoipdvvlnvbe
# 42    frenchquarter you have a pepper palace at 1 ma...
# 43    pjbowles4 meltinginmarana rkline56 alexpatriot...
# ...                                                 ...
# 5951  great job fellas🇺🇸 cnn ✌maga2020 \ncnnispapara...
# 5953  realdonaldtrump  loves america\nhe loves us\na...
# 5955  maryulinger johntrumpfankjv i like your attitu...
# 5956           hoarsewisperer event is back on maga2020
# 5957  could not have said it better wterrence youll ...
# 5959  realdonaldtrump jairbolsonaro the mainstream l...
# 5961  time is on trumps side  kicking off the minnea...
# 5962  trumpminneapolis\n\ndamn people in rural ameri...
# 5963  thespeaker2018 what the \n\nin reality i guess...
# 5965  patriotcitizen4 disneyhero323 in hopes maga ac...
# 5967  awesome retweet to keep it sweet maga2020 http...
# 5970  watching now \nhis campaigning style is what g...
# 5971  i have never been polled and voting for trump2...
# 5972  pismob erin2vankude ilhanmn thursdaymotivation...
# 5976  watching live super excited maga2020 kag2020 h...
# 5977  dear maga2020 when trump denied knowing giulia...
# 5978  judicialwatch i wish you all would leave this ...
# 5983  bettemidler adamparkhomenko i love ewarren and...
# 5984  repadamschiff this is more than ‘removing’ a d...
# 5985  thought this was a blue state😂😂kag2020 maga202...
# 5986  incredible maga meetup in pa tonight full of s...
# 5987  how fakenewsmedia outlets are in the front lin...
# 5989  richzeoli interesting choice should really tan...
# 5990  gopchairwoman bwwings realdonaldtrump hey left...
# 5991  watching the trump rally\nmaga2020\nusa usa us...
# 5993  thank you to all my friends for sharing pictur...
# 5994  thank you to all my friends for sharing pictur...
# 5995  trump’s children take in millions overseas as ...
# 5997  🚨breaking🚨\nwhistleblower worked with joebiden...
# 5998  gosh imagine that a spineless business failure...
#
#                                          word_freq_list  \
# 0     [dollars, trump2020, relate, themmaga, keep, e...
# 1     [thanks, magachallenge, shame, httpstcoj847bf4...
# 3     [needs, wallace, weather, time, switch, shep👉🏻...
# 4     [stable, withdrawal, –, ⁦potus⁩, correct, http...
# 5                   [maga2020, joemaga, joebiden, poor]
# 6     [maga, magachallenge, found, trumpminneapolisr...
# 7     [maga2020, worth, home, fort, police, httpstco...
# 8     [birthday, happy, wishing, httpstcozqi9xttlcv,...
# 10    [🇺🇸⚖️✌️🏼😉, good, week, said, case, winning, ma...
# 11    [maga, httpstcoizlfu3jlao, winning, founder, i...
# 13    [youre, never, wait, nbc, oh, mind, nbcnews, u...
# 15    [cook, tradwife, yeah, httpstconm6fqmfsnq, lib...
# 16    [assholes, lying, fakenews…, well, httpstcor9j...
# 17    [house, fast, day, 2020, come, ’, gopleader, m...
# 18    [release, picking, zelden, bad, about…, cherry...
# 21    [debramessing, another, broken, googlenews, an...
# 22    [realdonaldtrump, getting, pulled, exactly, br...
# 24     [pay, kiphenley, nice, maga2020, mortgage, week]
# 27    [stevehiltonx, and…, foxnews, wait, httpstcolh...
# 28    [maga, httpstcoygj8d1w9gm, protect, responsibl...
# 29    [repadamschiff, saracarterdc, messages, text, ...
# 30    [resident, aaand, martina, ’, right…, person, ...
# 31    [maga2020landslide, patriots, democratsarecorr...
# 32                       [maga2020, billkristol, drunk]
# 34    [maga, way, go, maga2020landslide, moron, resi...
# 35                     [davidjharrisjr, hell, maga2020]
# 38    [n…, controlled, watch, media, 6, corps, mind,...
# 41                       [httpstcoipdvvlnvbe, maga2020]
# 42    [across, pepper, market, nola…, palace, burn, ...
# 43    [rkline56, 1badveteran, ganncro, meltinginmara...
# ...                                                 ...
# 5951  [job, cnn, fellas🇺🇸, ✌maga2020, httpstcovao7tk...
# 5953  oreyears, loves, maga2020…, love, us, https...
# 5955  [maga, takebackthehouse, attitude, johntrumpfa...
# 5956            [hoarsewisperer, event, maga2020, back]
# 5957  [maga, tonite…, mn, equalitytownhall, wterrenc...
# 5959  [leftie, repulsive, brazil, mainstream, stands...
# 5961  [kicking, minneapolistrumprally, kag2020landsl...
# 5962  [damn, rural, dumb, believe, trumpminneapolis,...
# 5963  [thespeaker2018, httpstcotd53pzjsqm, peoplethe...
# 5965  [maga, never, pay, disneyhero323, attention, a...
# 5967  [awesome, retweet, sweet, httpstcodmsx6b6s1c, ...
# 5970  [maga, maga2020, watching, style, elected, htt...
# 5971  [never, voting, trump2020, httpstcodpnabugsvh,...
# 5972  [ilhanmn, thursdaymotivation, one, support, 4️...
# 5976  [watching, httpstcoxtxh188cmw, live, excited, ...
# 5977  [attended, knowing, trump, httpstconysuoxtl9e,...
# 5978  [wish, in…, woman, electoral, alone, worth, wo...
# 5983  [bettemidler, kamalaharris, httpstcoys1lw2dvea...
# 5984  [deepstate, duly, httpstcoajeiakwmdi, anything...
# 5985  [minneapolistrumprally, thought, httpstco4oc3y...
# 5986  [maga, full, support, 2020, tonight, meetup, i...
# 5987  [outlets, cognitivedissonance, lionelnation🇺🇸,...
# 5989  [really, interesting, vote, tank, trump2020, z...
# 5990  [neighborh…, hey, bwwings, unless, one, httpst...
# 5991  [fkn, watching, rally, usa, httpstcour3g7bdlag...
# 5993  [thank, minnesota…, httpstcov83pwp0hod, trump,...
# 5994  [thank, minnesota…, trump, rally, ’, president...
# 5995  [take, president, son, ’, children, trump, htt...
# 5997  [🚨breaking🚨, httpstcox0cjtigzhe, obamawhitehou...
# 5998  [bill…, gosh, business, doesnt, stiffing, pay,...
#
#                             comments_attributes_replace
# 0     dollars trump relate themmaga keep elites maga...
# 1     thanks magachallenge shame httpstcoj847bf4s3n ...
# 3     needs immigrationace weather time switch shep👉...
# 4     stable withdrawal – ⁦potus⁩ correct httpstcoka...
# 5                         maga2020 bidenmaga biden poor
# 6     maga magachallenge found trumpminneapolisrally...
# 7     maga2020 worth home fort police httpstcor9urgg...
# 8     birthday happy wishing httpstcozqi9xttlcv eric...
# 10    🇺🇸⚖️✌️🏼😉 good week said case winning maga2020 ...
# 11    maga httpstcoizlfu3jlao winning founder foreig...
# 13    youre never wait nbc oh mind nbcnews unfounded...
# 15    cook tradwife yeah httpstconm6fqmfsnq libtards...
# 16    assholes lying fakenews… well httpstcor9j5hrqo...
# 17    house fast day 2020 come ’ gopleader maga2020 ...
# 18    release picking zelden bad about… cherry bette...
# 21    debramessing another broken googlenews anniega...
# 22    realtrump getting pulled exactly bravo excelle...
# 24            pay kiphenley nice maga2020 mortgage week
# 27    stevehiltonx and… foxnews wait httpstcolhnlhk7...
# 28    maga httpstcoygj8d1w9gm protect responsible ku...
# 29    repadamschiff saracarterdc messages text admit...
# 30    resident aaand martina ’ right… person mattlas...
# 31    maga2020landslide patriots democratsarecorrupt...
# 32                           maga2020 billkristol drunk
# 34    maga way go maga2020landslide moron resign htt...
# 35                         davidjharrisjr hell maga2020
# 38    n… gun_control_controlled watch media 6 corps ...
# 41                          httpstcoipdvvlnvbe maga2020
# 42    across pepper market nola… palace burn frenchq...
# 43    rkline56 1badveteran ganncro meltinginmarana h...
# ...                                                 ...
# 5951  economy cnn fellas🇺🇸 ✌maga2020 httpstcovao7tkj...
# 5953  4moreyears loves maga2020… love us httpstcoycs...
# 5955  maga takebackthehouse attitude johntrumpfankjv...
# 5956                 hoarsewisperer event maga2020 back
# 5957  maga tonite… mn equalitytownhall wterrence sai...
# 5959  leftie repulsive brazil mainstream stands disg...
# 5961  kicking minneapolistrumprally kag2020landslide...
# 5962  damn rural dumb believe trumpminneapolis dirt ...
# 5963  thespeaker2018 httpstcotd53pzjsqm peoplethey p...
# 5965  maga never pay disneyhero323 attention accts h...
# 5967  awesome retweet sweet httpstcodmsx6b6s1c maga2...
# 5970  maga maga2020 watching style elected httpstcog...
# 5971  never voting trump httpstcodpnabugsvh polled w...
# 5972  ilhanmn thursdaymotivation one support 4️⃣5️⃣t...
# 5976  watching httpstcoxtxh188cmw live excited super...
# 5977  attended knowing trump httpstconysuoxtl9e dear...
# 5978  wish in… woman electoral alone worth would htt...
# 5983  bettemidler kamalaharris httpstcoys1lw2dvea me...
# 5984  deepstate duly httpstcoajeiakwmdi anything ’ a...
# 5985  minneapolistrumprally thought httpstco4oc3y2b9...
# 5986  maga full support 2020 tonight meetup incredib...
# 5987  outlets cognitivedissonance lionelnation🇺🇸 … v...
# 5989  really interesting vote tank trump zeoliarmy f...
# 5990  neighborh… hey bwwings unless one httpstcorher...
# 5991  fkn watching rally usa httpstcour3g7bdlag maga...
# 5993  thank minnesota… httpstcov83pwp0hod trump rall...
# 5994  thank minnesota… trump rally ’ president frien...
# 5995  take president son ’ children trump httpstcof4...
# 5997  🚨breaking🚨 httpstcox0cjtigzhe obamawhitehouse ...
# 5998  bill… gosh business doesnt stiffing pay spinel...
#
# [3975 rows x 8 columns]

# %%
people_trump = ['trump','battleground']
trump_df = pd.DataFrame(columns = people_trump)

def candidates_mentioned(item):
    if p.lower() in item.lower():
        return 1
    else:
        return 0
      
for p in people_trump:
    trump_df[p] = data1['tweets'].apply(candidates_mentioned)
    
    
    
people_dem = ['biden','battleground']
dem_df = pd.DataFrame(columns = people_dem)

def candidates_mentioned(item):
    if p.lower() in item.lower():
        return 1
    else:
        return 0
      
for p in people_dem:
    dem_df[p] = data1['tweets'].apply(candidates_mentioned)

# %%
liftratio1=pd.DataFrame(columns = people_trump)
for i in range(len(people_trump)):
    new_list = []
    for j in range(len(people_trump)):
        if (i!=j):
            numerator = ((trump_df[people_trump[i]] + trump_df[people_trump[j]]) > 1).sum()
            denominator = trump_df[people_trump[j]].sum()*trump_df[people_trump[i]].sum()
            lift = numerator*len(trump_df)/denominator
            liftratio1.loc[people_trump[i],people_trump[j]] = lift
print ('Below are the lift ratios among Trump and battleground')
liftratio1
# Out:
# Below are the lift ratios among Trump and battleground
#                trump battleground
# trump            NaN       1.0759
# battleground  1.0759          NaN

# %%
liftratio2=pd.DataFrame(columns = people_dem)
for i in range(len(people_dem)):
    new_list = []
    for j in range(len(people_dem)):
        if (i!=j):
            numerator = ((dem_df[people_dem[i]] + dem_df[people_dem[j]]) > 1).sum()
            denominator = dem_df[people_dem[j]].sum()*dem_df[people_dem[i]].sum()
            lift = numerator*len(dem_df)/denominator
            liftratio2.loc[people_dem[i],people_dem[j]] = lift
print ('Below are the lift ratios among Biden and battleground')
liftratio2
# Out:
# Below are the lift ratios among Biden and battleground
#               biden battleground
# biden           NaN        1.886
# battleground  1.886          NaN

# %% [markdown]
# ## Lift analysis

# %%
liftdf = pd.DataFrame(index=['Battleground'],columns=['Trump','Biden'])
liftdf.iloc[0,0]=liftratio1.iloc[0,1]
liftdf.iloc[0,1]=liftratio2.iloc[0,1]
liftdf
# Out:
#                Trump  Biden
# Battleground  1.0759  1.886

# %%
data2 = data1[data1['User Location'] == 'battleground']

# %%
#get the compound sentiment score of tweets mentioned Trump
trumpsenti=[]
analyzer = SIA()
for index, row in data2.iterrows():
    if 'trump' in row['tweets'].lower():
        vs = analyzer.polarity_scores(row['tweets'])
        trumpsenti.append(vs['compound'])

# %%
#get the compound sentiment score of tweets mentioned Biden
demsenti=[]
analyzer = SIA()
for index, row in data2.iterrows():
    if 'biden' in row['tweets'].lower():
        vs = analyzer.polarity_scores(row['tweets'])
        demsenti.append((vs['compound']))

# %%
# take the average semtiment score of each tweet
import numpy as np
sentimentdf = pd.DataFrame(index=['Battleground'],columns=['Trump','Biden'])
sentimentdf.iloc[0,0]=np.mean(trumpsenti)
sentimentdf.iloc[0,1]=np.mean(demsenti)
sentimentdf
# Out:
#                 Trump      Biden
# Battleground  0.14784  0.0489545

# %%
# a more detailed report of people's sentiment when they talk about Trump
trumppos = 0
trumpneg = 0
for x in trumpsenti:
    if x>0:
        trumppos+=1
    if x<0:
        trumpneg+=1
trumppos = trumppos/len(trumpsenti)
trumpneg = trumpneg/len(trumpsenti)


print(str(trumppos*100) +"% of tweets have postive sentiments regarding to Trump in battleground.")
print(str((1-trumpneg-trumppos)*100) +"% of tweets have neutral sentiments regarding to Trump in battleground.")
print(str(trumpneg*100) +"% of tweets have negitive sentiments regarding to Trump in battleground.")
# Out:
# 43.28358208955223% of tweets have postive sentiments regarding to Trump in battleground.
# 37.3134328358209% of tweets have neutral sentiments regarding to Trump in battleground.
# 19.402985074626866% of tweets have negitive sentiments regarding to Trump in battleground.

# %%
# a more detailed report of people's sentiment when they talk about Biden
bidenpos = 0
bidenneg = 0
for x in demsenti:
    if x>0:
        bidenpos+=1
    if x<0:
        bidenneg+=1
        
bidenpos = bidenpos/len(demsenti)
bidenpos = bidenneg/len(demsenti)


print(str(bidenpos*100) +"% of tweets have postive sentiments regarding to Biden in battleground.")
print(str((1-bidenpos-bidenpos)*100) +"% of tweets have neutral sentiments regarding to Biden in battleground.")
print(str(bidenpos*100) +"% of tweets have negitive sentiments regarding to Biden in battleground.")
# Out:
# 27.27272727272727% of tweets have postive sentiments regarding to Biden in battleground.
# 45.45454545454546% of tweets have neutral sentiments regarding to Biden in battleground.
# 27.27272727272727% of tweets have negitive sentiments regarding to Biden in battleground.

# %% [markdown]
# # Part F

# %% [markdown]
# According to the lift analysis, Trump is associated more with immigration and impeach issues than Biden. While Biden is more associated with economy and foreign relations issues. According to the sentiment analysis, people have very diverse sentiments of Trump and Biden on different issues. As for economy issue, people’s overall sentiment of Trump is positive. On the other hand, Biden is not favorable because the sentiment score is negative. For immigration issue, Biden is favorable, and Trump is not liked. As for foreign relations, both candidates are not favorable. However, people still prefer Trump compared to Biden. For impeach issue, Trump is more favorable than Biden. And people’ssentiment of Biden is neutral on impeach issue.Trump should improve his reputation on immigration and foreign relation issues, because on these issues Biden is favorable. Our recommendation is that he should not post too many twittes abouthis politics. Even he wants to post something on Twitter, he should not show the aggressiveness because it will make people dislike him. Especially for immigration and foreign relation issues, on whichpeople show negative sentiments. As for Biden, he should work on improving his recognition on solvingeconomy and impeach issues, since Trump is preferred compared to him on these two issues. What’s more, he should increase the frequency of posting twittes. Because Trump posts a lot, and it will shift the focus away from him.  According to the result of lift analysis Trump is not frequently discussed in Michigan, Pennsylvania and Wisconsin. The probability of Trump been discussed is less than random selection. Compared to Trump, Biden is much more likely to be discussed by people in Michigan, Pennsylvania and Wisconsin. The probability of Biden been discussed is significantly higher than random selection. According to the result of sentiment analysis, for people in Michigan, Pennsylvania and Wisconsin, theirsentiments about Trump is more positive than their sentiments about Biden. In other words, Trump is more favorable in Michigan, Pennsylvania and Wisconsin, compared to Biden. After combining the lift analysis and the sentiment analysis, we are confidence to conclude that although Biden is mentioned more in people’s discussions, it is likely that those mentions are close to neutral sentiments. Although Trump is mentioned less frequently, people in Michigan, Pennsylvania and Wisconsin like him more than Biden. Trump should give more speeches in Michigan, Pennsylvania and Wisconsin. Because he is favorable compared to Biden. By giving more speeches, people will discuss him more, and it is beneficial. Biden should participate more on Twitter and speak for people’s benefits; therefore, he would have a chance to have higher sentiment score than Trump.
